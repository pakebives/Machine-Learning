# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Ecommerce Customers.csv')

# %% [markdown]
# Two first rows:

# %%
data.head(2)
# Out:
#                        Email                                         Address  \
# 0  mstephenson@fernandez.com    835 Frank Tunnel\nWrightmouth, MI 82180-9605
# 1          hduke@hotmail.com  4547 Archer Common\nDiazchester, CA 06566-8576
#
#       Avatar  Avg. Session Length  Time on App  Time on Website  \
# 0     Violet            34.497268    12.655651        39.577668
# 1  DarkGreen            31.926272    11.109461        37.268959
#
#    Length of Membership  Yearly Amount Spent
# 0              4.082621           587.951054
# 1              2.664034           392.204933

# %%
x = dataset.iloc[:, 3:7].values
X = dataset.iloc[:, 6:7].values  # relacion entre x y y

# %%
y = dataset.iloc[:, 7:].values #amount spent

# %%
X
# Out:
# array([[4.08262063],
#        [2.66403418],
#        [4.1045432 ],
#        [3.12017878],
#        [4.44630832],
#        [5.4935072 ],
#        [4.68501725],
#        [4.43427343],
#        [3.27343358],
#        [3.20280607],
#        [2.48260777],
#        [3.7132092 ],
#        [4.04642316],
#        [3.91854184],
#        [2.49454365],
#        [3.35784684],
#        [3.13613272],
#        [2.42080616],
#        [1.51657558],
#        [4.06454855],
#        [4.59993736],
#        [1.55915194],
#        [2.24514779],
#        [3.91930231],
#        [5.70515397],
#        [2.72173599],
#        [4.64819932],
#        [2.99636453],
#        [3.92348875],
#        [4.74257752],
#        [3.06236815],
#        [3.47141345],
#        [4.34306292],
#        [2.82009723],
#        [4.1245853 ],
#        [3.64928616],
#        [1.84737042],
#        [3.45238858],
#        [4.65049127],
#        [4.22243623],
#        [4.67127546],
#        [4.64611998],
#        [4.21449509],
# ...

# %%
y
# Out:
# array([[587.95105397],
#        [392.20493344],
#        [487.54750487],
#        [581.85234404],
#        [599.40609205],
#        [637.10244792],
#        [521.57217476],
#        [549.90414611],
#        [570.20040896],
#        [427.1993849 ],
#        [492.60601272],
#        [522.33740461],
#        [408.64035107],
#        [573.41586733],
#        [470.4527333 ],
#        [461.7807422 ],
#        [457.84769594],
#        [407.70454755],
#        [452.31567548],
#        [605.0610388 ],
#        [534.70574381],
#        [419.93877484],
#        [436.51560573],
#        [519.34098913],
#        [700.91709162],
#        [423.17999168],
#        [619.89563986],
#        [486.83893477],
#        [529.53766534],
#        [554.72208383],
#        [497.5866713 ],
#        [447.68790654],
#        [588.71260551],
#        [491.07322368],
#        [507.44183234],
#        [521.88357317],
#        [347.77692663],
#        [490.73863214],
#        [478.17033405],
#        [537.84619527],
# ...

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.scatter(X,y,color='blue')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=0)   # 0.3 significa que cojo data de 30% y el 70% restante es usado como train

# %%
x_test
# Out:
# array([[32.4914466 , 12.53035737, 37.8752191 ,  2.47613905],
#        [32.7111193 , 12.32629139, 36.67387836,  3.35027929],
#        [33.07773079, 11.46698422, 35.67572763,  1.80922959],
#        [32.21292383, 11.73299146, 35.63395395,  4.33186303],
#        [32.77049216, 11.37176736, 35.26149812,  4.03438613],
#        [30.73772037, 12.63660605, 36.21376309,  3.35784684],
#        [33.56647439, 12.23565925, 37.27757338,  2.53204406],
#        [32.24635   , 11.30555143, 37.13312676,  1.70738973],
#        [34.56868085, 11.37808709, 38.30447119,  3.78493211],
#        [31.94539575, 12.96576148, 36.9663889 ,  6.07665364],
#        [32.68624509, 12.63857212, 36.09722093,  4.29773748],
#        [32.67294353, 12.27605698, 37.19279353,  3.98247151],
#        [35.86023651, 11.73066139, 36.88214908,  3.41620998],
#        [34.39432665, 12.80775183, 38.55103029,  1.81007988],
#        [31.86483255, 13.44340599, 36.87831537,  2.36108695],
# ...

# %%
y_test
# Out:
# array([[449.07031944],
#        [482.60246733],
#        [374.26967454],
#        [513.15311185],
#        [502.77107457],
#        [461.7807422 ],
#        [466.42119882],
#        [327.37795259],
#        [528.22380937],
#        [657.01992394],
#        [571.47103412],
#        [523.63393514],
#        [546.55666686],
#        [467.4278485 ],
#        [439.89128048],
#        [445.06218551],
#        [553.99467359],
#        [403.7669021 ],
#        [595.80381888],
#        [490.73863214],
#        [712.39632681],
#        [502.0925279 ],
#        [398.16346853],
#        [570.45172591],
#        [549.86059046],
#        [392.99225591],
#        [419.93877484],
#        [407.65717876],
#        [521.14295181],
#        [463.74598112],
#        [556.29814117],
#        [506.54730705],
#        [514.33655827],
#        [476.76672415],
#        [418.6027421 ],
#        [403.81951983],
#        [506.13234244],
#        [436.72055586],
#        [558.94811239],
#        [421.32663126],
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict = model.predict(x_test)

# %%
y_predict[10]
# Out:
# array([559.9744863])
